# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.width', 1000)

# %%
# Load the CSV file from Google Drive
file_path = '/content/drive/My Drive/combined_appliances_data.csv'
combined = pd.read_csv(file_path)

# %%
combined.head(10)
# Out:
#                 event_time event_type  product_id          category_id                        category_code     brand   price    user_id                          user_session
# 0  2019-10-01 00:00:00 UTC       view     3900821  2053013552326770905  appliances.environment.water_heater      aqua   33.20  554748717  9333dfbd-b87a-4708-9857-6336556b0fcc
# 1  2019-10-01 00:00:11 UTC       view     2900536  2053013554776244595         appliances.kitchen.microwave  elenberg   51.46  555158050  b5bdd0b3-4ca2-4c55-939e-9ce44bb50abd
# 2  2019-10-01 00:00:13 UTC       view     3900746  2053013552326770905  appliances.environment.water_heater     haier  102.38  555444559  98b88fa0-d8fa-4b9d-8a71-3dd403afab85
# 3  2019-10-01 00:00:18 UTC       view    10900029  2053013555069845885             appliances.kitchen.mixer     bosch   58.95  519528062  901b9e3c-3f8f-4147-a442-c25d5c5ed332
# ...

# %%
import pandas as pd

# Assuming your DataFrame is named 'combined'
# Uncomment the next line if you are loading the DataFrame from a CSV file
# combined = pd.read_csv('path_to_your_dataset.csv')

# Convert event_time to datetime
combined['event_time'] = pd.to_datetime(combined['event_time'])

# Create new columns for date, hour, and day
combined['date'] = combined['event_time'].dt.date
combined['hour'] = combined['event_time'].dt.hour
combined['day'] = combined['event_time'].dt.day

# Display the first few rows to verify
combined.head()
# Out:
#                  event_time event_type  product_id          category_id                        category_code     brand   price    user_id                          user_session        date  hour  day
# 0 2019-10-01 00:00:00+00:00       view     3900821  2053013552326770905  appliances.environment.water_heater      aqua   33.20  554748717  9333dfbd-b87a-4708-9857-6336556b0fcc  2019-10-01     0    1
# 1 2019-10-01 00:00:11+00:00       view     2900536  2053013554776244595         appliances.kitchen.microwave  elenberg   51.46  555158050  b5bdd0b3-4ca2-4c55-939e-9ce44bb50abd  2019-10-01     0    1
# 2 2019-10-01 00:00:13+00:00       view     3900746  2053013552326770905  appliances.environment.water_heater     haier  102.38  555444559  98b88fa0-d8fa-4b9d-8a71-3dd403afab85  2019-10-01     0    1
# ...

# %%
combined.head(250)
# Out:
#                    event_time event_type  product_id          category_id                           category_code             brand    price    user_id                          user_session        date  hour  day
# 0   2019-10-01 00:00:00+00:00       view     3900821  2053013552326770905     appliances.environment.water_heater              aqua    33.20  554748717  9333dfbd-b87a-4708-9857-6336556b0fcc  2019-10-01     0    1
# 1   2019-10-01 00:00:11+00:00       view     2900536  2053013554776244595            appliances.kitchen.microwave          elenberg    51.46  555158050  b5bdd0b3-4ca2-4c55-939e-9ce44bb50abd  2019-10-01     0    1
# 2   2019-10-01 00:00:13+00:00       view     3900746  2053013552326770905     appliances.environment.water_heater             haier   102.38  555444559  98b88fa0-d8fa-4b9d-8a71-3dd403afab85  2019-10-01     0    1
# ...

# %%
# Save the transformed DataFrame to a new CSV file
combined_file_path = '/content/drive/My Drive/combined_file_path.csv'
combined.to_csv(combined_file_path, index=False)
print(f"Filtered DataFrame saved to {combined_file_path}")

# Download the file if needed
from google.colab import files
files.download(combined_file_path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-d7b982869d33> in <cell line: 3>()
#       1 # Save the transformed DataFrame to a new CSV file
#       2 combined_file_path = '/content/drive/My Drive/combined_file_path.csv'
# ----> 3 combined.to_csv(combined_file_path, index=False)
#       4 print(f"Filtered DataFrame saved to {combined_file_path}")
#       5
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3770         )
#    3771
# -> 3772         return DataFrameRenderer(formatter).to_csv(
#    3773             path_or_buf,
#    3774             lineterminator=lineterminator,
#
# ...
